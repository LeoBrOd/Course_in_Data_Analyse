# %%
"""
Install the Google AI Python SDK

$ pip install google-generativeai
"""

import os
import google.generativeai as genai

genai.configure(api_key="")

# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
)

chat_session = model.start_chat()

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Titanic-Dataset.csv")
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
response = chat_session.send_message("INSERT_INPUT_HERE")

print(response.text)

# %%
query = """Analyze the correlation between passenger age and survival rates in the Titanic dataset, breaking down the analysis by age groups (e.g., children, adults, seniors). Provide statistical insights."

1. Formulate the query as specified.

2. Anonymize sensitive information (columns Name, Cabin, Ticket) before analysis in a single function.

3. Process the dataset in batches if necessary.

4. Interpret ChatGPT's insights and perform statistical analysis.

5. Visualize the results using appropriate charts or graphs.

6. Discuss the findings and draw conclusions."""

# %%
chat_session = chat_session.send_message(f"""
here is your data: {df.head(20)}
please {query}


""")

# %%
print(chat_session.text)
# Out:
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
#
# def anonymize_data(df):
#   """Anonymizes sensitive data in the DataFrame.
#
#   Args:
#     df: The DataFrame to anonymize.
#
#   Returns:
#     The anonymized DataFrame.
#   """
#   df = df.copy()
#   df['Name'] = 'Passenger'
#   df['Cabin'] = 'Unknown'
#   df['Ticket'] = 'XXXXXXXX'
#   return df
#
# def analyze_age_survival(df):
#   """Analyzes the correlation between passenger age and survival rates.
#
#   Args:
#     df: The DataFrame to analyze.
#
#   Returns:
#     A DataFrame with survival rates for each age group.
#   """
#   df = df.copy()
#   df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 18, 65, 100], labels=['Children', 'Teenagers', 'Adults', 'Seniors'])
#   survival_rates = df.groupby('AgeGroup')['Survived'].mean()
#   return survival_rates
#
# # Load the dataset
# data = """PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  Fare  Cabin Embarked
# ...
