# %% [markdown]
# Exercises XP Gold

# %% [markdown]
# Exercise 1 : Export A Dataframe To JSON With Orient (Easy)

# %%
import pandas as pd

# %%
data = {
'UserID': range(1, 11),
'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma',
         'Frank', 'Grace', 'Hannah', 'Ian', 'Jane'],
'Age': [25, 30, 35, 40, 29, 34, 28, 31, 36, 33],
'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix',
         'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose']
}
df = pd.DataFrame(data)
df.to_json('df',orient='table')

# %% [markdown]
# Exercise 2: Export A Dataframe From Excel

# %%
data = pd.DataFrame({
'Date': pd.date_range('20210101', periods=20),
'Product': ['Product A', 'Product B', 'Product C'] * 6 + ['Product A', 'Product B'],
'Quantity': [2, 3, 5, 7, 1] * 4,
'Revenue': [210.50, 340.60, 450.30, 120.10, 150.75] * 4
})

# %%
import openpyxl

# %%
wb = Workbook()
sheet = wb.active
data_list = data.values.tolist()
for row in data_list:
    sheet.append(row)
quantity_format = "0"
for cell in sheet["C"]:
  cell.number_format = quantity_format
revenue_format = "#,##0.00"
for cell in sheet["D"]:
  cell.number_format = revenue_format
header_font = openpyxl.styles.Font(bold=True, size=14)
wb.save("formatted_data.xlsx")
