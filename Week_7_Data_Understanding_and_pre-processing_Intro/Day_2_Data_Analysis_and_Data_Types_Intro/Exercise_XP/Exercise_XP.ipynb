# %%
from google.colab import files
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Exercise 2: Dataset Loading And Initial Analysis

# %%
import pandas as pd
clean_dataset = pd.read_csv('clean_dataset.csv')
crx = pd.read_csv('crx.csv')
tass = pd.read_csv('Time Americans Spend Sleeping.csv')
mhdd_data = pd.read_csv('Mental health Depression disorder Data.csv')
# Out:
# <ipython-input-10-5f04fe0c6ae9>:5: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mhdd_data = pd.read_csv('Mental health Depression disorder Data.csv')

# %%
print("Clean Dataset")
print(clean_dataset.head())
print("\nCrx")
print(crx.head())
print("\nTime Americans Spend Sleeping")
print(tass.head())
print("\nMental health Depression disorder Data")
print(mhdd_data.head())
# Out:
# Clean Dataset
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
print("Clean Dataset")
print(clean_dataset.info())
print("\nCrx")
print(crx.info())
print("\nTime Americans Spend Sleeping")
print(tass.info())
print("\nMental health Depression disorder Data")
print(mhdd_data.info())
# Out:
# Clean Dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# ...

# %% [markdown]
# Exercise 4: Exploring Data Types

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2f91dd6e-f980-4eda-a075-dd1c966f879b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f91dd6e-f980-4eda-a075-dd1c966f879b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris_data = pd.read_csv('Iris.csv')

# %%
print("Iris Dataset")
print(iris_data.head())
# Out:
# Iris Dataset
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# *   SepalLengthCm – quantitative
# *   SepalWidthCm – quantitative
# *   PetalLengthCm – quantitative
# *   PetalWidthCm – quantitative
# *   Species – qualitive

# %% [markdown]
# Exercise 5: Basic Data Analysis With Google Colab

# %%
import matplotlib.pyplot as plt

sepalLength = {
      "mean": iris_data['SepalLengthCm'].mean(),
      "median": iris_data['SepalLengthCm'].median(),
      "mode": iris_data['SepalLengthCm'].mode().iloc[0]
  }
sepalWidth = {
      "mean": iris_data['SepalWidthCm'].mean(),
      "median": iris_data['SepalWidthCm'].median(),
      "mode": iris_data['SepalWidthCm'].mode().iloc[0]
  }
petalLength = {
      "mean": iris_data['PetalLengthCm'].mean(),
      "median": iris_data['PetalLengthCm'].median(),
      "mode": iris_data['PetalLengthCm'].mode().iloc[0]
  }
petalWidth = {
      "mean": iris_data['PetalWidthCm'].mean(),
      "median": iris_data['PetalWidthCm'].median(),
      "mode": iris_data['PetalWidthCm'].mode().iloc[0]
  }
print(sepalLength)

plt.plot(iris_data['SepalWidthCm'])
plt.show()
# Out:
# {'mean': 5.843333333333334, 'median': 5.8, 'mode': 5.0}

# %% [markdown]
# Exercise 6: Basic Observation Skills In Data Analysis

# %%
print(tass)
# Out:
#      index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0        0  2003  Annual                      8.57           0.018
# 1        1  2004  Annual                      8.55           0.026
# 2        2  2005  Annual                      8.62           0.023
# 3        3  2006  Annual                      8.63           0.024
# 4        4  2007  Annual                      8.57           0.024
# ..     ...   ...     ...                       ...             ...
# 940    940  2013  Annual                      8.83           0.085
# 941    941  2014  Annual                      8.98           0.086
# 942    942  2015  Annual                      8.83           0.074
# 943    943  2016  Annual                      8.92           0.071
# 944    944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity    Sex
# 0               All days  15 years and over  Sleeping   Both
# ...

# %% [markdown]
# We can research:
# *   Type of days
# *   Age group
# *   Sex
#
# This columns could help us to better understand customer needs and make specific product for every group.
