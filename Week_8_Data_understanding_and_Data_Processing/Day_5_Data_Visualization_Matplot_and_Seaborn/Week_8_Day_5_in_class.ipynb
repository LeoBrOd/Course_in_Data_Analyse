# %%
import pandas as pd

# %%
data={'Country': ['Canada' , 'Canada' , 'Canada' , 'Canada', 'Canada', 'Canada', 'USA', 'USA' , 'USA'],
'City': ['Toronto' , 'Toronto' , 'Toronto', 'Vancouver', 'Vancouver', 'Vancouver', 'New York', 'New York', 'New York'], 'Date': ['2024-06-01', '2024-06-02' , '2024-06-03', '2024-06-01' , '2024-06-02' , '2024-06-03', '2024-06-01', '2024-06-02', '2024-06-03'], 'Temperature': [25, 31, 28, 22, 35, 24, 29, 32, 30], 'Precipitation': [5, 0, 10, 15, 0, 20, 3, 2, 1]}
df=pd.DataFrame(data)

# %%
data = df.set_index(['Country', 'City', 'Date'],inplace=True)

# %%
canada_data = df.loc['Canada']
print(canada_data)
# Out:
#                       Temperature  Precipitation
# City      Date
# Toronto   2024-06-01           25              5
#           2024-06-02           31              0
#           2024-06-03           28             10
# Vancouver 2024-06-01           22             15
#           2024-06-02           35              0
#           2024-06-03           24             20

# %%
heatwave_days = canada_data[canada_data['Temperature'] > 30]
print(heatwave_days)
# Out:
#                       Temperature  Precipitation
# City      Date
# Toronto   2024-06-02           31              0
# Vancouver 2024-06-02           35              0

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.

# %%
# Sample data
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

# Create a new figure
plt.figure()

# Plot x and y
plt.plot(x, y)

# Show the plot
plt.show()

# %%
# Sample data
categories = ['Category A', 'Category B', 'Category C']
values = [3, 7, 2]

# Create a bar chart
plt.bar(categories, values)

# Show the plot
plt.show()

# %%
# Sample data
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, color='green', linestyle='dashed', linewidth=2, marker='o',
         markerfacecolor='blue', markersize=12)
plt.show()

# %%
y2 = [0, 1, 8, 27, 64]

plt.plot(x, y, label='x squared')
plt.plot(x, y2, label='x cubed', color='red')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Multiple Lines with Legend')
plt.legend()
plt.show()

# %%
plt.plot(x, y, label='x squared')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Simple Line Plot with Labels and Title')
plt.legend()
plt.show()

# %% [markdown]
# Task #3

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv('sample_data/california_housing_train.csv')
#
# ...

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
streets = df[df['population'] > 800]
print(streets)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(df[ 'population' ], bins=30, edgecolor='k')
plt. title ('Distribution of Population')
plt.xlabel( 'Population')
plt. ylabel('Frequency' )
plt. show()

# %%
few_houses_threshold = 100
high_price_threshold = df['median_house_value' ].quantile(0.75)
filtered_df = df[~((df['households' ] < few_houses_threshold) & (df['median_house_value' ] > high_price_threshold) ) ]
print("Filtered DataFrame:")
print(filtered_df)
# Out:
# Filtered DataFrame:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt. scatter(filtered_df[ 'population' ], filtered_df[ 'median_house_value'], alpha=0.5)
plt. title('Median House Value Based on Population')
plt. xlabel( 'Population')
plt.ylabel ( 'Median House Value' )
plt. show()

# %%
# Data
brands = ['Apple', 'Samsung', 'Huawei', 'Xiaomi', 'Others']
market_share = [40, 30, 15, 10, 5]

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(market_share, labels=brands, autopct='%1.1f%%')
plt.title('Smartphone Market Share 2023')
plt.show()

# %%
# Sample data
import numpy as np
data = np.random.randn(100)

plt.boxplot(data)
plt.title('Basic Box Plot')
plt.ylabel('Values')
plt.show()

# %%
data1 = np.random.normal(100, 10, 200)
data2 = np.random.normal(90, 20, 200)
data3 = np.random.normal(80, 30, 200)

data = [data1, data2, data3]

fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

# Creating axes instance and the box plot
bp = ax.boxplot(data, patch_artist = True, notch = True, vert = 0)

# Changing color and line width of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='blue', linewidth = 1.5, linestyle =":")

# Changing color and line width of the caps
for cap in bp['caps']:
    cap.set(color ='red', linewidth = 2)

# Changing color and linewidth of the medians
for median in bp['medians']:
    median.set(color ='green', linewidth = 3)

# Changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D', color ='#e7298a', alpha = 0.5)

# Adding title
plt.title('Customized Box Plot')
plt.show()

# %%
# Create a figure and a set of subplots
fig, (ax1, ax2) = plt.subplots(2, 1)

# First subplot
ax1.plot([1, 2, 3], [1, 4, 9])
ax1.set_title('First Subplot')

# Second subplot
ax2.plot([1, 2, 3], [1, 2, 3])
ax2.set_title('Second Subplot')

# Show the figure
plt.show()

# %%
# Creating a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)

# Plotting different types of plots
axs[0, 0].plot([1, 2, 3], [3, 2, 1])
axs[0, 1].bar(['A', 'B', 'C'], [3, 2, 1])
axs[1, 0].scatter([1, 2, 3], [1, 4, 9])
axs[1, 1].hist([1, 1, 2, 3, 3, 3, 4, 4], bins=[1, 2, 3, 4, 5])
# Out:
# (array([2., 1., 3., 2.]),
#  array([1., 2., 3., 4., 5.]),
#  <BarContainer object of 4 artists>)

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True)

ax1.plot([1, 2, 3], [2, 3, 4])
ax2.plot([1, 2, 3], [4, 3, 2])

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Line plot
ax1.plot([1, 2, 3], [3, 2, 1])
ax1.set_title('Line Plot')

# Bar plot
ax2.bar(['A', 'B', 'C'], [3, 2, 1])
ax2.set_title('Bar Chart')

plt.show()

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.xlim(0, 10)  # setting x-axis limit
plt.ylim(-1.5, 1.5)  # setting y-axis limit
plt.grid(True, which='both', linestyle='--', linewidth=0.5)  # custom grid lines
plt.title("Sine Wave with Custom Axes and Grid")
plt.show()

# %%
from matplotlib.widgets import Slider

# %%
# Initial data
t = np.linspace(0, 1, 1000)
initial_freq = 5
y = np.sin(2 * np.pi * initial_freq * t)

fig, ax = plt.subplots()
plt.subplots_adjust(left=0.1, bottom=0.25)
l, = ax.plot(t, y)

# Slider
axfreq = plt.axes([0.1, 0.1, 0.65, 0.03])
freq_slider = Slider(axfreq, 'Freq', 0.1, 30.0, valinit=initial_freq)

# Update function
def update(val):
    freq = freq_slider.val
    l.set_ydata(np.sin(2 * np.pi * freq * t))
    fig.canvas.draw_idle()

# Connect the update function to the slider
freq_slider.on_changed(update)

plt.show()

# %%
from matplotlib.animation import FuncAnimation

# %%
fig, ax = plt.subplots()  # Create the figure and axes

# Array for x-axis values (128 points from 0 to 2*pi)
xdata = np.linspace(0, 2*np.pi, 128)
# Array for y-axis values (sine of corresponding x values)
ydata = np.sin(xdata)
ln, = ax.plot(xdata, ydata, 'r-', animated=True)  # Plot an empty line with animation enabled

def init():
  ax.set_xlim(0, 2*np.pi)
  ax.set_ylim(-1, 1)
  return ln,

def update(frame):
  xdata.append(frame)
  ydata.append(np.sin(frame))
  ln.set_data(xdata, ydata)
  return ln,

# Generate frames for animation (linspace was missing a closing parenthesis)
frames = np.linspace(0, 2*np.pi, 128)

ani = FuncAnimation(fig, update, frames=frames, init_func=init, blit=True)

plt.show()
