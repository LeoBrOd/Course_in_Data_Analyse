# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Scenario: You are a data analyst working with a dataset of global weather. Your task is to analyze temperature trends and visualize the results.
# 2. Deliverables:
#   * A Jupyter Notebook containing all the code for data generation, analysis, and visualization.
#   * A brief report within the notebook summarizing your findings, including the city with the highest and lowest average temperatures and any interesting trends observed in the data.
# 3. Evaluation Criteria:
#   * Correctness and efficiency of NumPy and Pandas code used for data manipulation.
#   * Effectiveness of data visualization in conveying the temperature trends.
#   * Clarity and conciseness of the summary report.

# %%
city=np.array(f"City {i}" for i in range(1,11))
month= ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
temperatures=np.random.uniform(low=-5, high=35, size=(10, 12))
df=pd.DataFrame(temperatures, columns=month, index=city)
print(df)
# Out:
#                Jan        Feb        Mar        Apr        May        Jun  \
# City 1   23.752052   3.980858  14.958559  -1.789614  21.271430  33.978746
# City 2    3.243696   0.151305   9.978871   5.276361   3.576901  24.178544
# City 3   12.581775  22.047157  16.968733   2.897525  13.283434   7.843509
# City 4    0.166802  25.778310  11.675960  -3.295500  21.038895   7.754225
# City 5   27.304575  32.366964  32.133803  10.941179  22.313751   9.458860
# City 6    6.263013  30.446149  -0.833607  18.911845  15.887412  10.467304
# City 7   28.910684   6.752396   3.606433  17.481295  33.175686   7.423375
# City 8   34.509319  -1.232239  16.601754  14.120660  26.742908  29.814200
# City 9   17.348873  24.771595  21.083631  24.450584  34.608354   5.505353
# City 10   1.110704   2.626626  -0.028420   4.768936  15.497999  34.594375
#
#                Jul        Aug        Sep        Oct        Nov        Dec
# City 1    7.344288   6.929528   3.151632  28.672308  19.100969   4.279309
# ...

# %%
avg_temp=df.mean(axis=1)
low_avg_city=avg_temp.idxmin()
high_avg_city=avg_temp.idxmax()
print("City with the lowest average temperature:", low_avg_city)
print("City with the highest average temperature:", high_avg_city)
# Out:
# City with the lowest average temperature: City 4
# City with the highest average temperature: City 5

# %%
plt.figure(figsize=(14, 7))
for city, city_temps in df.iterrows():
    plt.plot(city_temps.index, city_temps.values)
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.title("Monthly Temperature Trends for each City")
plt.legend(df.index)
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# %%
df_transposed = df.T
fig = px.line(df_transposed)
fig.update_layout(title="Monthly Temperature Trends for each City")
fig.update_xaxes(title="Month")
fig.update_yaxes(title="Temperature (°C)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * I made two charts, cause I think plotly more clear for user
#
# * from code that I ran:
#   * City with the lowest average temperature: City 4
#   * City with the highest average temperature: City 5
